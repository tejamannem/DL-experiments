# %% [markdown]
# <a href="https://colab.research.google.com/github/tejamannem/DL-experiments/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

# %%
data=pd.read_csv("/content/WineQT.csv")
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encode=LabelEncoder()
data["quality"]=encode.fit_transform(data["quality"])
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
X=data[data.columns[5:7]][:400]
X
# Out:
#      free sulfur dioxide  total sulfur dioxide
# 0                   11.0                  34.0
# 1                   25.0                  67.0
# 2                   15.0                  54.0
# 3                   17.0                  60.0
# 4                   11.0                  34.0
# ..                   ...                   ...
# 395                 14.0                  44.0
# 396                 32.0                  96.0
# 397                 10.0                  23.0
# 398                 10.0                  17.0
# 399                 10.0                  23.0
#
# [400 rows x 2 columns]

# %%
y=data["quality"][:400]

# %%
X_train,X_val,y_train,y_val=train_test_split(X,y,test_size=0.2,random_state=24)

# %%
X_train = np.array(X_train, dtype=float)

# %%
from sklearn.preprocessing import LabelEncoder
plt.title("Plot between free sulphur dioxide and total sulphur dioxide")
plt.scatter(X[y==3]["free sulfur dioxide"],X[y==3]["total sulfur dioxide"],color="red")
plt.scatter(X[y==2]["free sulfur dioxide"],X[y==2]["total sulfur dioxide"],color="blue")
plt.legend()
plt.plot()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# []
